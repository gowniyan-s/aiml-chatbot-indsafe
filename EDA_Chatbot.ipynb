# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import pandas as pd
sns.set(style="darkgrid")

# %%
df = pd.read_csv('IHMStefanini_industrial_safety_and_health_database_with_accidents_description.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                 Data   Countries     Local Industry Sector  \
# 0           0  2016-01-01 00:00:00  Country_01  Local_01          Mining
# 1           1  2016-01-02 00:00:00  Country_02  Local_02          Mining
# 2           2  2016-01-06 00:00:00  Country_01  Local_03          Mining
# 3           3  2016-01-08 00:00:00  Country_01  Local_04          Mining
# 4           4  2016-01-10 00:00:00  Country_01  Local_04          Mining
#
#   Accident Level Potential Accident Level Genre Employee or Third Party  \
# 0              I                       IV  Male             Third Party
# 1              I                       IV  Male                Employee
# 2              I                      III  Male    Third Party (Remote)
# 3              I                        I  Male             Third Party
# 4             IV                       IV  Male             Third Party
#
#          Critical Risk                                        Description
# ...

# %%
#shape
df.shape
# Out:
# (425, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425 entries, 0 to 424
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                425 non-null    int64
#  1   Data                      425 non-null    object
#  2   Countries                 425 non-null    object
#  3   Local                     425 non-null    object
#  4   Industry Sector           425 non-null    object
#  5   Accident Level            425 non-null    object
#  6   Potential Accident Level  425 non-null    object
#  7   Genre                     425 non-null    object
#  8   Employee or Third Party   425 non-null    object
#  9   Critical Risk             425 non-null    object
#  10  Description               425 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 36.6+ KB

# %% [markdown]
# Column  implication from the data source
#
# Data: timestamp or time/date information
# Countries: which country the accident occurred (anonymized)
# Local: the city where the manufacturing plant is located (anonymized)
# Industry sector: which sector the plant belongs to
# Accident level: from I to VI, it registers how severe was the accident (I means not severe but VI means very severe)
# Potential Accident Level: Depending on the Accident Level, the database also registers how severe the accident could have been (due to other factors involved in the accident)
# Genre: if the person is male of female
# Employee or Third Party: if the injured person is an employee or a third party
# Critical Risk: some description of the risk involved in the accident
# Description: Detailed description of how the accident happened.

# %%
# no null values
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Data                        0
# Countries                   0
# Local                       0
# Industry Sector             0
# Accident Level              0
# Potential Accident Level    0
# Genre                       0
# Employee or Third Party     0
# Critical Risk               0
# Description                 0
# dtype: int64

# %%
# no duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# looking or unique values
for col in ['Countries','Local','Industry Sector','Accident Level','Potential Accident Level','Genre','Employee or Third Party','Critical Risk']:
    print(col ,'###',df[col].unique())
# Out:
# Countries ### ['Country_01' 'Country_02' 'Country_03']
# Local ### ['Local_01' 'Local_02' 'Local_03' 'Local_04' 'Local_05' 'Local_06'
#  'Local_07' 'Local_08' 'Local_10' 'Local_09' 'Local_11' 'Local_12']
# Industry Sector ### ['Mining' 'Metals' 'Others']
# Accident Level ### ['I' 'IV' 'III' 'II' 'V']
# Potential Accident Level ### ['IV' 'III' 'I' 'II' 'V' 'VI']
# Genre ### ['Male' 'Female']
# Employee or Third Party ### ['Third Party' 'Employee' 'Third Party (Remote)']
# Critical Risk ### ['Pressed' 'Pressurized Systems' 'Manual Tools' 'Others'
#  'Fall prevention (same level)' 'Chemical substances' 'Liquid Metal'
#  'Electrical installation' 'Confined space'
#  'Pressurized Systems / Chemical Substances'
#  'Blocking and isolation of energies' 'Suspended Loads' 'Poll' 'Cut'
#  'Fall' 'Bees' 'Fall prevention' '\nNot applicable' 'Traffic' 'Projection'
#  'Venomous Animals' 'Plates' 'Projection/Burning' 'remains of choco'
# ...

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
df['Date'].nunique()
# Out:
# 287

# %%
#univarate

# %%
sns.countplot(df['Countries'])
#relatively large majority of the data is from country_01

# %%
df['Countries'].value_counts(normalize=True)
# Out:
# Country_01    0.590588
# Country_02    0.305882
# Country_03    0.103529
# Name: Countries, dtype: float64

# %%
df['Local'].value_counts(normalize=True)
# Out:
# Local_03    0.211765
# Local_05    0.138824
# Local_01    0.134118
# Local_04    0.131765
# Local_06    0.108235
# Local_10    0.103529
# Local_08    0.063529
# Local_02    0.056471
# Local_07    0.032941
# Local_12    0.009412
# Local_09    0.004706
# Local_11    0.004706
# Name: Local, dtype: float64

# %%
sns.countplot(df['Local'])
#relatively large majority of the data is from local_03

# %%
df['Industry Sector'].value_counts(normalize=True)
# Out:
# Mining    0.567059
# Metals    0.315294
# Others    0.117647
# Name: Industry Sector, dtype: float64

# %%
sns.countplot(df['Industry Sector'])
#relatively large majority of the data is from mining

# %%
df['Accident Level'].value_counts(normalize=True)
# Out:
# I      0.743529
# II     0.094118
# III    0.072941
# IV     0.070588
# V      0.018824
# Name: Accident Level, dtype: float64

# %%
sns.countplot(df['Accident Level'])
#relatively large majority of the data is from accident level1

# %%
df['Potential Accident Level'].value_counts(normalize=True)
# Out:
# IV     0.336471
# III    0.249412
# II     0.223529
# I      0.115294
# V      0.072941
# VI     0.002353
# Name: Potential Accident Level, dtype: float64

# %%
sns.countplot(df['Potential Accident Level'])
#relatively large majority of the data was potential level iv

# %%
df['Genre'].value_counts(normalize=True)
# Out:
# Male      0.948235
# Female    0.051765
# Name: Genre, dtype: float64

# %%
sns.countplot(df['Genre'])
#majority of the data is got the gender male

# %%
df['Employee or Third Party'].value_counts(normalize=True)
# Out:
# Third Party             0.444706
# Employee                0.421176
# Third Party (Remote)    0.134118
# Name: Employee or Third Party, dtype: float64

# %%
sns.countplot(df['Employee or Third Party'])
# majority of data is of third party employees followed closely by employee or third party

# %%
df['Critical Risk'].value_counts(normalize=True)
# Out:
# Others                                       0.545882
# Pressed                                      0.056471
# Manual Tools                                 0.047059
# Chemical substances                          0.040000
# Venomous Animals                             0.037647
# Cut                                          0.032941
# Projection                                   0.030588
# Bees                                         0.023529
# Fall                                         0.021176
# Vehicles and Mobile Equipment                0.018824
# Pressurized Systems                          0.016471
# remains of choco                             0.016471
# Fall prevention (same level)                 0.016471
# Suspended Loads                              0.014118
# Fall prevention                              0.014118
# Liquid Metal                                 0.007059
# Pressurized Systems / Chemical Substances    0.007059
# ...

# %%
plt.setp(sns.countplot(df['Critical Risk']).get_xticklabels(), rotation=90)
#majority of critial risk is classified as others
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# checking accident level and critical risk districution across various factors

# %%
sns.countplot(df['Countries'], hue = df['Accident Level'])
#We can infer the below:
#accident level 1 is highest across all countries 
#Accindent level1 is highest in country 1 (also country with majority of data)
#Accident level v(most severe) data is present in country 1 only

# %%
sns.countplot(df['Countries'], hue = df['Critical Risk'])
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
# All countires have maximum data under other

# %%
sns.countplot(df['Local'], hue = df['Accident Level'])
#local_03 has maximum data under accident level1
#local_03 and loca_04 have highest level for ccident level v

# %%
sns.set(rc={'figure.figsize':(23,10)})
sns.countplot(df['Local'], hue = df['Critical Risk'])
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
#local_03 has the highesh level of other critical risk

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(df['Industry Sector'], hue = df['Accident Level'])
#Mining sector has the highest number of level 1 accidents
#Mining sector has the higest number of level v accidents

# %%
sns.countplot(df['Industry Sector'], hue = df['Critical Risk'])
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
# Mining sector has the highest number of critical risk others

# %%
df.groupby(['Industry Sector', 'Critical Risk'])['Industry Sector'].count().sort_values().groupby(level=0).tail(3)
# Out:
# Industry Sector  Critical Risk
# Mining           Vehicles and Mobile Equipment      8
#                  Projection                         9
# Others           Bees                              10
#                  Venomous Animals                  13
# Metals           Chemical substances               15
#                  Pressed                           17
# Others           Others                            20
# Metals           Others                            33
# Mining           Others                           179
# Name: Industry Sector, dtype: int64

# %%
sns.countplot(df['Employee or Third Party'], hue = df['Accident Level'])
# Accident level v has been caused mainly by third party and third party remote
# we cannot ascertain about level 1 accidents as they may have been caused by Third party or employee

# %%
sns.countplot(df['Employee or Third Party'], hue = df['Critical Risk'])
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)

# %%
df.groupby(['Employee or Third Party', 'Critical Risk'])['Employee or Third Party'].count().sort_values().groupby(level=0).tail(3)
# Out:
# Employee or Third Party  Critical Risk
# Third Party (Remote)     Manual Tools             6
#                          Chemical substances      6
# Third Party              Bees                     9
# Employee                 Chemical substances      9
#                          Pressed                 12
# Third Party              Venomous Animals        12
# Third Party (Remote)     Others                  23
# Employee                 Others                 100
# Third Party              Others                 109
# Name: Employee or Third Party, dtype: int64

# %% [markdown]
# # Text pre processing

# %%
df['Description'][4]
# Out:
# 'Approximately at 11:45 a.m. in circumstances that the mechanics Anthony (group leader), Eduardo and Eric Fernández-injured-the three of the Company IMPROMEC, performed the removal of the pulley of the motor of the pump 3015 in the ZAF of Marcy. 27 cm / Length: 33 cm / Weight: 70 kg), as it was locked proceed to heating the pulley to loosen it, it comes out and falls from a distance of 1.06 meters high and hits the instep of the right foot of the worker, causing the injury described.'
